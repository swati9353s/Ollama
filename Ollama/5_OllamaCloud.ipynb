# %%
pip install ollama
# Out:
# Requirement already satisfied: ollama in e:\anaconda\lib\site-packages (0.6.0)
# Requirement already satisfied: httpx>=0.27 in e:\anaconda\lib\site-packages (from ollama) (0.28.1)
# Requirement already satisfied: pydantic>=2.9 in e:\anaconda\lib\site-packages (from ollama) (2.12.0)
# Requirement already satisfied: anyio in e:\anaconda\lib\site-packages (from httpx>=0.27->ollama) (4.2.0)
# Requirement already satisfied: certifi in e:\anaconda\lib\site-packages (from httpx>=0.27->ollama) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in e:\anaconda\lib\site-packages (from httpx>=0.27->ollama) (1.0.9)
# Requirement already satisfied: idna in e:\anaconda\lib\site-packages (from httpx>=0.27->ollama) (2.10)
# Requirement already satisfied: h11>=0.16 in e:\anaconda\lib\site-packages (from httpcore==1.*->httpx>=0.27->ollama) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\anaconda\lib\site-packages (from pydantic>=2.9->ollama) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.1 in e:\anaconda\lib\site-packages (from pydantic>=2.9->ollama) (2.41.1)
# Requirement already satisfied: typing-extensions>=4.14.1 in e:\anaconda\lib\site-packages (from pydantic>=2.9->ollama) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\anaconda\lib\site-packages (from pydantic>=2.9->ollama) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in e:\anaconda\lib\site-packages (from anyio->httpx>=0.27->ollama) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ollama 

response = ollama.generate(
    model="deepseek-v3.1:671b-cloud",
    prompt="Why do stars twinkle?"
)
print(response["response"])
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[7], line 3
#       1 import ollama
# ----> 3 response = ollama.generate(
#       4     model="deepseek-v3.1:671b-cloud",
#       5     prompt="Why do stars twinkle?"
#       6 )
#       7 print(response["response"])
#
# File E:\Anaconda\Lib\site-packages\ollama\_client.py:256, in Client.generate(self, model, prompt, suffix, system, template, context, stream, think, raw, format, images, options, keep_alive)
#     229 def generate(
#     230   self,
#     231   model: str = '',
#    (...)
#     244   keep_alive: Optional[Union[float, str]] = None,
#     245 ) -> Union[GenerateResponse, Iterator[GenerateResponse]]:
#     246   """
#     247   Create a response using the requested model.
#     248
#    (...)
#     253   Returns `GenerateResponse` if `stream` is `False`, otherwise returns a `GenerateResponse` generator.
#     254   """
# --> 256   return self._request(
#     257     GenerateResponse,
#     258     'POST',
#     259     '/api/generate',
#     260     json=GenerateRequest(
#     261       model=model,
#     262       prompt=prompt,
#     263       suffix=suffix,
#     264       system=system,
#     265       template=template,
#     266       context=context,
#     267       stream=stream,
#     268       think=think,
#     269       raw=raw,
#     270       format=format,
#     271       images=list(_copy_images(images)) if images else None,
#     272       options=options,
#     273       keep_alive=keep_alive,
#     274     ).model_dump(exclude_none=True),
#     275     stream=stream,
#     276   )
#
# File E:\Anaconda\Lib\site-packages\ollama\_client.py:189, in Client._request(self, cls, stream, *args, **kwargs)
#     185         yield cls(**part)
#     187   return inner()
# --> 189 return cls(**self._request_raw(*args, **kwargs).json())
#
# File E:\Anaconda\Lib\site-packages\ollama\_client.py:133, in Client._request_raw(self, *args, **kwargs)
#     131   return r
#     132 except httpx.HTTPStatusError as e:
# --> 133   raise ResponseError(e.response.text, e.response.status_code) from None
#     134 except httpx.ConnectError:
#     135   raise ConnectionError(CONNECTION_ERROR_MESSAGE) from None
#
# ResponseError: unauthorized (status code: 401)
